# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import plot_partial_dependence
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore") 

# %matplotlib inline

# %%
# Creating features
x1 = [np.random.normal(10, 2) for x in range(1000)]
x2 = [math.sin(x) for x in x1]
x3 = [np.random.normal(0.3, 1.5) for x in range(1000)]

# %%
# Adding label
y = [x + y + z for (x, y, z) in list(zip(x1, x2, x3))]

# %%
# Creating Dataframe
df = pd.DataFrame({"x1": x1, "x2": x2, "x3": x3, "y": y})

# %%
# Visualizing Correlations
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(method="spearman"), annot=True, vmax=1, vmin=-1)
plt.title("Inter-Correlations between features and labels", fontsize = 15)
plt.show()

# %%
# Visualizing the relations between features and label
plt.figure(figsize=(8, 6))
plt.scatter(x1, y, c="r", alpha=0.4, label="X1: Gaussian Dist w/ μ:10.0, σ:2.0")
plt.scatter(x2, y, c="b", alpha=0.4, label="X2: sin(X1)")
plt.scatter(x3, y, c="y", alpha=0.4, label="X3: Gaussian Dist w/ μ:0.3, σ:1.5")
plt.legend()
plt.title("Scatter Plot of Relations between Features and Label", fontsize = 15)
plt.xlabel("Features")
plt.ylabel("Outcome")
plt.show()

# %%
# Cleaning up
scaled_vals = StandardScaler().fit_transform(df.iloc[:, :-1])
scaled_df = pd.DataFrame(scaled_vals, columns=['x1', 'x2', 'x3'])
scaled_df['y'] = y
scaled_df

X = scaled_df.iloc[:, :-1]
y = scaled_df.iloc[:, -1]

# %%
# Building Model
est = RandomForestRegressor()
est.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Analyzing PDP plots
fig = plt.gcf()
fig.set_size_inches(15,6)
features = ['x1', 'x2', 'x3']
plot_partial_dependence(est, X, features, fig = fig)
fig.suptitle("Partial dependence on Partially Co-related Features", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Partial dependence on Partially Co-related Features')
